# %%
root='/Users/sachinmishra/Desktop/nyt'
os.getcwd()
os.chdir(root)
os.getcwd()
# Out:
# '/Users/sachinmishra/Desktop/nyt'

# %%
import glob
filenames = glob.glob('*.tmp')

# %%
print(filenames)
# Out:
# ['nyt-007631.tmp', 'nyt-005998.tmp', 'nyt-007625.tmp', 'nyt-002013.tmp', 'nyt-002007.tmp', 'nyt-007619.tmp', 'nyt-007433.tmp', 'nyt-007427.tmp', 'nyt-006739.tmp', 'nyt-006077.tmp', 'nyt-006711.tmp', 'nyt-006705.tmp', 'nyt-006063.tmp', 'nyt-006936.tmp', 'nyt-006922.tmp', 'nyt-001903.tmp', 'nyt-001917.tmp', 'nyt-001888.tmp', 'nyt-007547.tmp', 'nyt-006881.tmp', 'nyt-007553.tmp', 'nyt-006895.tmp', 'nyt-006665.tmp', 'nyt-006671.tmp', 'nyt-006842.tmp', 'nyt-006856.tmp', 'nyt-001877.tmp', 'nyt-001863.tmp', 'nyt-002629.tmp', 'nyt-000002.tmp', 'nyt-000003.tmp', 'nyt-002628.tmp', 'nyt-001862.tmp', 'nyt-001876.tmp', 'nyt-006857.tmp', 'nyt-006843.tmp', 'nyt-006670.tmp', 'nyt-006664.tmp', 'nyt-006894.tmp', 'nyt-007552.tmp', 'nyt-001889.tmp', 'nyt-006880.tmp', 'nyt-007546.tmp', 'nyt-001916.tmp', 'nyt-001902.tmp', 'nyt-006923.tmp', 'nyt-006937.tmp', 'nyt-006704.tmp', 'nyt-006062.tmp', 'nyt-006076.tmp', 'nyt-006710.tmp', 'nyt-006738.tmp', 'nyt-007426.tmp', 'nyt-007432.tmp', 'nyt-002006.tmp', 'nyt-00
# ...

# %%
allfiles = os.listdir(root)

# %%
allfiles
# Out:
# ['nyt-007631.tmp',
#  'nyt-005998.tmp',
#  'nyt-007625.tmp',
#  'nyt-002013.tmp',
#  'nyt-002007.tmp',
#  'nyt-007619.tmp',
#  'nyt-007433.tmp',
#  'nyt-007427.tmp',
#  'nyt-006739.tmp',
#  'nyt-006077.tmp',
#  'nyt-006711.tmp',
#  'nyt-006705.tmp',
#  'nyt-006063.tmp',
#  'nyt-006936.tmp',
#  'nyt-006922.tmp',
#  'nyt-001903.tmp',
#  'nyt-001917.tmp',
#  'nyt-001888.tmp',
#  'nyt-007547.tmp',
#  'nyt-006881.tmp',
#  'nyt-007553.tmp',
#  'nyt-006895.tmp',
#  'nyt-006665.tmp',
#  'nyt-006671.tmp',
#  'nyt-006842.tmp',
#  'nyt-006856.tmp',
#  'nyt-001877.tmp',
#  'nyt-001863.tmp',
#  'nyt-002629.tmp',
#  'nyt-000002.tmp',
#  'nyt-000003.tmp',
#  'nyt-002628.tmp',
#  'nyt-001862.tmp',
#  'nyt-001876.tmp',
#  'nyt-006857.tmp',
#  'nyt-006843.tmp',
#  'nyt-006670.tmp',
#  'nyt-006664.tmp',
#  'nyt-006894.tmp',
#  'nyt-007552.tmp',
#  'nyt-001889.tmp',
#  'nyt-006880.tmp',
#  'nyt-007546.tmp',
#  'nyt-001916.tmp',
#  'nyt-001902.tmp',
#  'nyt-006923.tmp',
#  'nyt-006937.tmp',
# ...

# %%
final=sorted(allfiles)

# %%
final
# Out:
# ['nyt-000000.tmp',
#  'nyt-000001.tmp',
#  'nyt-000002.tmp',
#  'nyt-000003.tmp',
#  'nyt-000004.tmp',
#  'nyt-000005.tmp',
#  'nyt-000006.tmp',
#  'nyt-000007.tmp',
#  'nyt-000008.tmp',
#  'nyt-000009.tmp',
#  'nyt-001797.tmp',
#  'nyt-001798.tmp',
#  'nyt-001799.tmp',
#  'nyt-001800.tmp',
#  'nyt-001801.tmp',
#  'nyt-001802.tmp',
#  'nyt-001803.tmp',
#  'nyt-001804.tmp',
#  'nyt-001805.tmp',
#  'nyt-001806.tmp',
#  'nyt-001807.tmp',
#  'nyt-001808.tmp',
#  'nyt-001809.tmp',
#  'nyt-001810.tmp',
#  'nyt-001811.tmp',
#  'nyt-001812.tmp',
#  'nyt-001813.tmp',
#  'nyt-001814.tmp',
#  'nyt-001815.tmp',
#  'nyt-001816.tmp',
#  'nyt-001817.tmp',
#  'nyt-001818.tmp',
#  'nyt-001819.tmp',
#  'nyt-001820.tmp',
#  'nyt-001821.tmp',
#  'nyt-001822.tmp',
#  'nyt-001823.tmp',
#  'nyt-001824.tmp',
#  'nyt-001825.tmp',
#  'nyt-001826.tmp',
#  'nyt-001827.tmp',
#  'nyt-001828.tmp',
#  'nyt-001829.tmp',
#  'nyt-001830.tmp',
#  'nyt-001831.tmp',
#  'nyt-001832.tmp',
#  'nyt-001833.tmp',
# ...

# %%
import os

# %%
import nltk
from nltk.tokenize import sent_tokenize

# %% [markdown]
# files='/Users/sachinmishra/Desktop/nyt/abc.txt'

# %%
files='/Users/sachinmishra/Desktop/nyt/abc.txt'

# %%
file= open(files,'r',encoding='utf-8')
text=file.read()
text=text.replace("\n", "")
sentences=nltk.tokenize.sent_tokenize(text, language='english')

#sentences=sent_tokenize(text)
print(sentences)
# Out:
# ['NEW YORK Kenneth Joseph Lenihan, a New York researchsociologist who helped refine the scientific methods used incriminology, died May 25 at his home in Manhattan.', 'He was 69.Lenihan retired in 1995 as an associate professor of sociologyat John Jay College of Criminal Justice.', "He had joined the facultyin 1980, after earlier stints as a researcher at ColumbiaUniversity's Bureau of Applied Social Research, the Vera Instituteof Justice in New York and the Bureau of Social Science Research inWashington.He brought his expertise to the study of recidivism rates amongcriminal offenders.", "He conducted a study in Baltimore, called theLife Project, for the U.S. Department of Labor in the early 1970s.Lenihan was born in Queens, and graduated from Columbia's Schoolof General Studies in 1960.", 'He also earned his M.A.', 'and Ph.D. insociology at Columbia, the latter in 1974.Lenihan is survived by two sons, Andrew of Miami, and William ofManhattan; a daughter, Jean Lenihan of Seattle; fou
# ...

# %%
final_file= 'final.txt'
with open(final_file, 'wb') as outfile:
    for i in sentences:
            outfile.write(i.encode())
            outfile.write('\n'.encode())
